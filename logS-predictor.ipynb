# %% [markdown]
# <a href="https://colab.research.google.com/github/nithya1365/food-guard-project/blob/main/logS-predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #prediction of logS

# %% [markdown]
# ##load the dataset

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/refs/heads/master/delaney_solubility_with_descriptors.csv')
df
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]

# %% [markdown]
# #**data** **prep**

# %% [markdown]
# ##separating data

# %%
y = df['logS']
x = df.drop('logS', axis = 1) #axis=1 makes sure that it displays the data in form of columns
x
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0     2.59540  167.850                0.0            0.000000
# 1     2.37650  133.405                0.0            0.000000
# 2     2.59380  167.850                1.0            0.000000
# 3     2.02890  133.405                1.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# ...       ...      ...                ...                 ...
# 1143  2.02164  179.219                1.0            0.461538
# 1144  2.37650  133.405                0.0            0.000000
# 1145  2.37650  133.405                0.0            0.000000
# 1146  2.30000    4.500                0.0            0.000000
# 1147  2.30000    4.500                0.0            0.100000
#
# [1148 rows x 4 columns]

# %% [markdown]
# ###split data as the training set and testing set

# %%
from sklearn.model_selection import train_test_split as tspl
x_train, x_test, y_train, y_test = tspl(x , y, test_size = 0.2 , random_state=100)  #this means the size of test will be 20% of the total data and train size will be 80% od entire data.

# %% [markdown]
# #building the model

# %% [markdown]
# ##traingin the model

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ##applying model to make a prediciton

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)
y_lr_test_pred
# Out:
# array([-3.05722870e+00, -7.77785827e+00, -2.55016650e+00, -2.01523582e+00,
#        -2.06375990e+00, -9.99672215e-01, -5.94603364e-01, -5.53626003e-01,
#        -5.72200956e+00, -3.94006681e+00, -3.95496755e+00, -2.29737009e+00,
#        -1.48980354e+00, -1.48988982e+00, -4.64510806e+00, -1.90396018e+00,
#        -1.51566313e+00, -3.16424605e+00, -3.70863920e+00, -5.58105660e+00,
#        -3.25038467e+00, -5.04235077e+00, -5.69194881e+00, -2.14339849e+00,
#        -4.35689341e+00, -5.03964756e+00, -3.10383618e+00, -4.40286964e+00,
#        -4.21276272e+00,  5.56508349e-01, -1.45537678e+00, -4.41027396e+00,
#        -2.59668773e+00, -1.53336276e+00, -5.55749874e-01, -1.67111795e+00,
#        -2.78163675e+00, -3.15395565e+00, -5.27083361e+00, -1.75321446e+00,
#        -1.53350725e+00, -2.01255666e+00, -6.57559167e+00, -7.89433046e+00,
#        -5.76437127e+00, -4.16422068e+00, -3.43694663e+00,  1.43834212e+00,
# ...

# %% [markdown]
# #model performnace check
# comparing predicted vals with actual data and seeing accuracy

# %%
from sklearn.metrics import mean_squared_error, r2_score
lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
lr_train_mse
# Out:
# 1.0075362951093687

# %%
lr_train_r2
# Out:
# 0.7645051774663391

# %%
lr_test_r2
# Out:
# 0.7891616188563282

# %%
lr_test_mse
# Out:
# 1.0206953660861033

# %%
lr_res = pd.DataFrame(['Linearregression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()

# %%
lr_res.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
lr_res.to_csv('lr_res.csv', index=False)
lr_res
# Out:
#                   0         1         2         3         4
# 0  Linearregression  1.007536  0.764505  1.020695  0.789162

# %% [markdown]
# #**main program**
# taking input from user and output is teh predicted logS value

# %%
print("enter values of MolLogP, MolWt, NumRotatableBonds, AromaticProportion to predict value of logS, separate using spaces and should be of type float")
mlp, mw, nrb, arp = input().split()

mlp = float(mlp)
mw = float(mw)
nrb = float(nrb)
arp = float(arp)

new_record = pd.DataFrame({
    'MolLogP': [mlp],
    'MolWt': [mw],
    'NumRotatableBonds': [nrb],
    'AromaticProportion': [arp]
})

# Step 3: Concatenate the new record with the existing DataFrame
df = pd.concat([df, new_record], ignore_index=True)

print("added to file succesfully")
new_rec = df.tail(1)[['MolLogP', 'MolWt', 'NumRotatableBonds', 'AromaticProportion']]
predval = lr.predict(new_rec)
print("\npredicted value is: logS= ", predval[0])
df.at[df.index[-1], 'logS'] = predval
# Out:
# enter values of MolLogP, MolWt, NumRotatableBonds, AromaticProportion to predict value of logS, separate using spaces and should be of type float
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-89d5f8c2476f> in <cell line: 2>()
#       1 print("enter values of MolLogP, MolWt, NumRotatableBonds, AromaticProportion to predict value of logS, separate using spaces and should be of type float")
# ----> 2 mlp, mw, nrb, arp = input().split()
#       3
#       4 mlp = float(mlp)
#       5 mw = float(mw)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...
